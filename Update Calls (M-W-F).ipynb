# %% [markdown]
# # Update calls
#
# **2016-09-26**
# Issues with event total in the display where the currency is not correct - does not correspond in view and database
# Should a report (which will be blank) be available for participants who didn't actually bid?
#
# Gaurav
# Table-type questions in testing
# Have chosen to deploy in staging so Nic can have a look at it
#
# Deepesh
# MD6639 - currencies change when copying templates to multi-currency events; corrected and pushed to lot template branch
# MD6640 - similar copy, but with different exchange ratios will result in the wrong exchange rate; corrected(?) and pushed to lot template branch
# MD6486 - Hiding details of completed lots/bids/phases when confusing or irrelevant; rank from qualification bids not valid when bid at lot level, etc.
#
# Nitin is away in hospital - not hiring replacement as yet
#
# Vijay
# MD6655 - Special characters on name, email, company name. Taking currency of host at time of creating licence but participant is also changing currency at time of bidding.
# MD6669 - 'RFQ' showing in reports even when participants have not placed any RFQ bids or situation is not an RFQ; RFQ bids are not used during auction for reasons of fairness.
#
# James
# MD6662 - Wiring view for picklists to the database so that users can create, edit and select picklists properly.
#
# **2016-09-28**
#
# Shobit
#  - Fixed copy-paste of questionnaire questions feature
#  - Pull request created
#
# Gaurav
#  - Checking report feature; issues discovered
#  - Continuing with testing; will submit report with issues and merge suggestions.
#  - Award Lots have been somewhat tested
#
# Deepesh
#  - MD6673 - feedback on table questions; validation errors changed question type!
#  - Added check to not refresh question on validation if table question (in controller); discussed making this a generic property for all question types.
#  - Fixed issues with row and column counts
#  - JS not being executed due to content_for; has been debugged and replaced with script.
#  - Date type questions chosen after table type question removed text boxes; has refactored relevant JS.
#  - MD6677 - Gaurav found irreproducible bugs; recheck as necessary.
#  - Exceptions while creating BLIC
#  - MD6478 - Queries on, addressing will be ongoing plan.
#
# Vijay
#  - MD6669 - Download report button; if event is RFQ and there is no existing bid, check and disable download report button.
#  - MD6675 - If participant changes currency in UOM does not reflect on report section; added fix to ensure that currencies remain in sync; get currency and conversion rate for participant side when report requested by participant.
#  - MD6670 - Multi-currency event; participant changes currencies report does not reflect the change. For Particpant text was not giving relevant text information.
#  - MD6678 - Currencies fix; ongoing plan.
#
# Nic
#  - Has been on Support, catch up with queries
#  - Look at planning for Aggreko requirements
#
# **2016-09-30**
#
# Shobit
#  - MD6633 - could not turn off question from client side; pr submitted but suboptimal solution so far. Split out the method and validated custom fields.
#  - MD6652 - Proxy submission for report sections; multi-choice insert was improperly aligned (visual).
#  - MD6632 - confirmation for submitting answer (multi-question, host provides proxy answer, progress bar internally submits and popup shows) When the host clicks sumbit and the form is submitted internally there is a clash. Button so far disabled, better solution on the way.
#
# Gaurav
#  - Testing on table type question; exceptions and design issues found. Digging ahead and looking at the UI.
#  - Start testing tickets currently submitted but not merged.
#  - Once PR merged, will move to testing more of Vijay's output.
#
# Deepesh
#  - MD6478: emails showing issues with multiple tickets. If the size doesn't exist give filename.size; adding to model.
#  - Document templates, document model, upload templates etc all deal with the files; has created helper method instead of altering everything.
#  - MD??66: moving questions under focus
#  - MD6683: if participant rejects lot or his event ends quickly the button is invisible; has used Vijay's helper method to fix the issue to check whether the event is completed and the participant is active.
#  - Table style questions in progress.
#  - Complex lot reports call hidden methods because one may be a duplicate in the wrong place.
#
# Vijay
#  - MD6678: three parts, bugfixing, PR and spec changes. Chained event helper, new methods, new view plus specs for that part. Moved to UM issue host enters price sale did not show correct quantity - corrected in new downloadable report.
#  - Currently working on MD6674. Event ID can't be searched for when cloning an existing event.
#  - Added to 5.2 release milestone.
#
# **2016-10-03**
#
# Shobit
# Updated PR, working on copy/pasting questions and sections
# MD6668 - exception when uploading invalid format files; all formatting is in Dropzone.js
# MD6621 - Proxy answer popup has issues with position of progress bar; current operation.
#
# Gaurav
# Reports testing; download reports button not displaying automatically when lot is completed; requires manual refresh
# Testing tickets; MD6678 in particular where participants enter weight in different scales (mg, kg etc)
#
# Deepesh
# MD6478 - JSON response for progress bars. Pages loses CSS on access due to Dropzone not being closed after a successful update.
# MD6692 - exception when deleting questionnaires. Could not reproduce error. Current situation is a cascade deletion; should work fine but is currently generating exceptions occasionally. Possibly a race condition.
# MD6682 - Question was not saved before being dragged to new position; failed. Now needs to save question as it is being created rather than after.
# MD6681 - fixed
# Currently working on CSS/UI issues.
#
# Vijay
# MD6694 - Award lots messages investigation
#
# Nic
# New frontend design was intended to be delivered today
# Not currently the case; slippage inevitable.
# iKantam working, but there will be an issue with integration because they're working from Master.
#
# **2016-10-05**
#
# Shobit
#
# 6603 - proxy answer timeout on pageload is used for progress bar; colour changed on pageload, now doesn't do so.
# Fixed minor IE9 issue regarding timeout.
# 6693 - spinner missing on save and submit button for participants
# 6519 - support queries on 'unable to place RFQ completed bids' message. Fixed and merged.
# 6702 - copy/paste sections in a questionnaire resulted in total weighting of 200%, which then failed to save when saved due to invalid weighting. Discussed cloning questionnaire even though parts are invalid, then fixing after clone.
#
# Gaurav
#
# Working on Vijay's report ticket regarding thrown exceptions; fixing locales esp with regard to currencies.
# Testing table questions integration.
#
# Deepesh
#
# 6682 - Making questions unsortable, then validate on save and ensure they stay that way
# 6478 - update progress bar when document is uploaded (AJAX); uses success callback to trigger value update
# 5829 - Moved relevant code to event model; nil object in array of document causes not saving correctly. May need to remove declarative authorisation from the relevant model.
#
# Nitin
#
# 1211 - Table type questions; adding limits to length of table headings. Correct validations using JS and RB
# 4438 - questions and answers, with and without participants
# 6681 - More table questions
# Plan 4439
#
# Vijay
#
# 6697 - Host ability to delete the bid created exceptions;
# 6698 - Showing currency on price sections in award lots; currency changes and price doesn't. Correcting view update (currency to symbol) - may cause issues with Excel or similar due to currency vs decimal formatting, and the report is an xls output.
# plan - work on these two tickets, plus creating message for retrieve
#
# Nic
#
# Visited customer (PHS); replacing their senior procurement team. Met with new consultants who have an existing competitor relationship.
# Plan to address issues with the mail systems.
# iKantam have indicated they need the rest of this week and then next week as well to complete their issues.
#
# **2016-10-07**
