# %% [markdown]
# # Initial thoughts (2016-09-13)
#
# Large codebase, nicely laid out. Lots of tests, which appear themselves to be well-written. Use of Rubocop, RSpec and Reek seen.
#
# Short on comments. Some use of TODO, a couple of HACKs, almost no NOTEs. No comment attributions **or dating** even for TODOs.
#
# The Users model is possibly the largest Ruby file I've ever seen. That could really do with breaking up if possible, it's a ridiculous size for what appears to be one class.
#
# Good use of Git & GitHub, in particular code reviews/pull requests.
#
# There appears to be a bug tracking system, but it's NOT the GitHub Issues system. Might need to find out why, given it's the primary collaboration platform.
#
# The company seems to make a lot of use of Skype. Best see if I can move them to Slack, for better multi-channel comms and collab tools, chat histories, bot-compatibility and so on. Hopefully will never be required to do voice or video chat; not stated either way but somewhat implied.
#
# # Bugs
#
#  - Test cases which rely on Time.now fail between 2300 and (some time after 00:45 but before 09:50) GMT. Before midnight is not the same as after midnight.
#   - Yes, seriously.
#   - No, I have no idea how that works either, yet.
#   - Issue appears to be an off-by-one error (in some cases); before midnight the result is `-1` from expectation, after midnight it is `+1`.
#   - Replicated three nights running.
#   - All tests work fine at 10:33 and 13:32.
#   - RSpec takes 7:30 to run, roughly; consider making a script to run it once every ten minutes for 24 hours and plot the number of failures?
#
#   **Two Examples before midnight (2016-09-14-2347)**
#
# ```
#    1) EventDecisionReportMethods to calculate scoring required #submission_lateness should return the correct date for a participant
#      Failure/Error: @event.submission_lateness(@event_participant1).should eq([0, :green])
#
#        expected: [0, :green]
#
#             got: [-1, :green]
#
#        (compared using ==)
#      # ./spec/lib/sim_dojo/event_decision_report_methods_spec.rb:282:in `block (4 levels) in <top (required)>'
#
#   2) EventDecisionReportMethods to calculate scoring required #decision_lateness should caluclate the date from last questionnaire removed if it is
#           greater than the last submitted date
#      Failure/Error: @event.decision_lateness(@event_participant1).should eq([30, :red])
#
#        expected: [30, :red]
#             got: [29, :red]
#
#        (compared using ==)
#      # ./spec/lib/sim_dojo/event_decision_report_methods_spec.rb:300:in `block (4 levels) in <top (required)>'
#
# ```
#
# **Twenty Examples after midnight (2016-09-15-0024)**
#
# ```
# 1) CategoryDojo::CategoriesController Catgory Permission user with create permission for portfolio with his own category should eq "Category has been successfully copied
# ."
#      Failure/Error: it { flash[:notice].should eq(I18n.t(:category_copy_msg)) }
#
#        expected: "Category has been successfully copied."
#             got: nil
#
#        (compared using ==)
#      # ./spec/controllers/category_dojo/categories_controller_spec.rb:58:in `block (5 levels) in <top (required)>'
#
#   2) EventDecisionReportMethods to calculate scoring required #scorer_lateness should return correct date for a user
#      Failure/Error: @event.scorer_lateness(@participant1.id)
#
#
#        expected: [0, :green]
#             got: [1, :green]
#
#        (compared using ==)
#      # ./spec/lib/sim_dojo/event_decision_report_methods_spec.rb:255:in `block (4 levels) in <top (required)>'
#
#   3) EventDecisionReportMethods to calculate scoring required #decision_lateness should return the correct date for a participant
#      Failure/Error: @event.decision_lateness(@event_participant1).should eq([0, :green])
#
#        expected: [0, :green]
#             got: [1, :green]
#
#        (compared using ==)
#      # ./spec/lib/sim_dojo/event_decision_report_methods_spec.rb:288:in `block (4 levels) in <top (required)>'
#
#   4) CategoryDojo::Category#copy_category_with_its_associations
#      Failure/Error: it { subject.name.should eql 'Copy of MD category' }
#      NoMethodError:
#        undefined method `name' for nil:NilClass
#      # ./spec/models/category_dojo/category_spec.rb:414:in `block (3 levels) in <top (required)>'
#
#   5) CategoryDojo::Category#copy_category_with_its_associations
#      Failure/Error: it { subject.category_current_experience.should_not be_nil  }
#      NoMethodError:
#        undefined method `category_current_experience' for nil:NilClass
#      # ./spec/models/category_dojo/category_spec.rb:415:in `block (3 levels) in <top (required)>'
#
#   6) CategoryDojo::Category#copy_category_with_its_associations
#      Failure/Error: it { subject.category_supply.should_not be_nil  }
#      NoMethodError:
#        undefined method `category_supply' for nil:NilClass
#      # ./spec/models/category_dojo/category_spec.rb:416:in `block (3 levels) in <top (required)>'
#
#   7) CategoryDojo::Category#copy_category_with_its_associations copied category's associated object should have same values
#      Failure/Error: subject.category_current_experience.accuracy_of_specs.should == md_category.category_current_experience.accuracy_of_specs
#      NoMethodError:
#        undefined method `category_current_experience' for nil:NilClass
#      # ./spec/models/category_dojo/category_spec.rb:419:in `block (3 levels) in <top (required)>'
#
#   8) CategoryDojo::Category#copy_category_with_its_associations dotted_ids should not be same
#
#      Failure/Error: subject.dotted_ids != md_category.dotted_ids
#      NoMethodError:
#        undefined method `dotted_ids' for nil:NilClass
#      # ./spec/models/category_dojo/category_spec.rb:422:in `block (3 levels) in <top (required)>'
#
#   9) QuestionnaireQuestionsAnswer Class methods for Script .duration_less_than_doc_expiry? should send notification according to the defined frequency
#      Failure/Error: result.should eq([@answer])
#
#        expected: [#<QuestionnaireQuestionsAnswer id: 1048181906, questionnaire_answer_id: 1016275370, questionnaire_question_id: 1061194218, manually_scored: true, given_s
# core: 0.0, content: "", created_at: "2016-09-14 23:19:43", updated_at: "2016-09-14 23:19:43", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-07 23:19:
# 43", current: true, archived_at: nil>]
#             got: []
#
#        (compared using ==)
#
#        Diff:
#        @@ -1,2 +1,2 @@
#        -[#<QuestionnaireQuestionsAnswer id: 1048181906, questionnaire_answer_id: 1016275370, questionnaire_question_id: 1061194218, manually_scored: true, given_score: 0.0
# , content: "", created_at: "2016-09-14 23:19:43", updated_at: "2016-09-14 23:19:43", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-07 23:19:43", curr
# ent: true, archived_at: nil>]
#        +[]
#
#      # ./spec/models/questionnaire_questions_answer_spec.rb:274:in `block (4 levels) in <top (required)>'
#
#   10) QuestionnaireQuestionsAnswer Class methods for Script .duration_less_than_doc_expiry? should resend notification if last notification failed
#      Failure/Error: result.should eq([@answer])
#
#        expected: [#<QuestionnaireQuestionsAnswer id: 1048181908, questionnaire_answer_id: 1016275372, questionnaire_question_id: 1061194222, manually_scored: true, given_s
# core: 0.0, content: "", created_at: "2016-09-14 23:19:43", updated_at: "2016-09-14 23:19:43", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-07 23:19:
# 43", current: true, archived_at: nil>]
#             got: []
#
#        (compared using ==)
#
#        Diff:
#        @@ -1,2 +1,2 @@
#        -[#<QuestionnaireQuestionsAnswer id: 1048181908, questionnaire_answer_id: 1016275372, questionnaire_question_id: 1061194222, manually_scored: true, given_score: 0.0
#
# , content: "", created_at: "2016-09-14 23:19:43", updated_at: "2016-09-14 23:19:43", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-07 23:19:43", curr
# ent: true, archived_at: nil>]
#        +[]
#
#      # ./spec/models/questionnaire_questions_answer_spec.rb:286:in `block (4 levels) in <top (required)>'
#
#   11) QuestionnaireQuestionsAnswer Class methods for Script .duration_less_than_doc_expiry? should not resend notification if just notified to participant
#      Failure/Error: result.should eq([@answer])
#
#        expected: [#<QuestionnaireQuestionsAnswer id: 1048181911, questionnaire_answer_id: 1016275375, questionnaire_question_id: 1061194228, manually_scored: true, given_s
# core: 0.0, content: "", created_at: "2016-09-14 23:19:44", updated_at: "2016-09-14 23:19:44", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-07 23:19:
# 44", current: true, archived_at: nil>]
#             got: []
#
#        (compared using ==)
#
#        Diff:
#        @@ -1,2 +1,2 @@
#        -[#<QuestionnaireQuestionsAnswer id: 1048181911, questionnaire_answer_id: 1016275375, questionnaire_question_id: 1061194228, manually_scored: true, given_score: 0.0
# , content: "", created_at: "2016-09-14 23:19:44", updated_at: "2016-09-14 23:19:44", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-07 23:19:44", curr
# ent: true, archived_at: nil>]
#        +[]
#
#      # ./spec/models/questionnaire_questions_answer_spec.rb:304:in `block (4 levels) in <top (required)>'
#
#  12) QuestionnaireQuestionsAnswer Class methods for Script .duration_less_than_doc_expiry? will continue sending the notification if not rejected the notifications which
# are already sent
#      Failure/Error: result.should eq([@answer])
#
#        expected: [#<QuestionnaireQuestionsAnswer id: 1048181912, questionnaire_answer_id: 1016275376, questionnaire_question_id: 1061194230, manually_scored: true, given_s
# core: 0.0, content: "", created_at: "2016-09-14 23:19:44", updated_at: "2016-09-14 23:19:44", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-07 23:19:
# 44", current: true, archived_at: nil>]
#             got: []
#
#        (compared using ==)
#
#        Diff:
#        @@ -1,2 +1,2 @@
#
#        -[#<QuestionnaireQuestionsAnswer id: 1048181912, questionnaire_answer_id: 1016275376, questionnaire_question_id: 1061194230, manually_scored: true, given_score: 0.0
# , content: "", created_at: "2016-09-14 23:19:44", updated_at: "2016-09-14 23:19:44", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-07 23:19:44", curr
# ent: true, archived_at: nil>]
#        +[]
#
#      # ./spec/models/questionnaire_questions_answer_spec.rb:314:in `block (4 levels) in <top (required)>'
#
#   13) QuestionnaireQuestionsAnswer Class methods for Script .duration_less_than_doc_expiry? should not resend notification if already notified
#      Failure/Error: result.should eq([@answer])
#
#        expected: [#<QuestionnaireQuestionsAnswer id: 1048181915, questionnaire_answer_id: 1016275379, questionnaire_question_id: 1061194236, manually_scored: true, given_s
# core: 0.0, content: "", created_at: "2016-09-14 23:19:45", updated_at: "2016-09-14 23:19:45", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-07 23:19:
# 45", current: true, archived_at: nil>]
#             got: []
#
#        (compared using ==)
#
#        Diff:
#        @@ -1,2 +1,2 @@
#        -[#<QuestionnaireQuestionsAnswer id: 1048181915, questionnaire_answer_id: 1016275379, questionnaire_question_id: 1061194236, manually_scored: true, given_score: 0.0
# , content: "", created_at: "2016-09-14 23:19:45", updated_at: "2016-09-14 23:19:45", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-07 23:19:45", curr
# ent: true, archived_at: nil>]
#        +[]
#
#      # ./spec/models/questionnaire_questions_answer_spec.rb:344:in `block (4 levels) in <top (required)>'
#
#
#   14) QuestionnaireQuestionsAnswer Class methods for Script .reject_if_already_sent should not reject the answers for which the notification needs to be sent
#      Failure/Error: final_result.should eq([@answer])
#
#        expected: [#<QuestionnaireQuestionsAnswer id: 1048181918, questionnaire_answer_id: 1016275382, questionnaire_question_id: 1061194242, manually_scored: true, given_s
# core: 0.0, content: "", created_at: "2016-09-14 23:19:46", updated_at: "2016-09-14 23:19:46", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-07 23:19:
# 46", current: true, archived_at: nil>]
#             got: []
#
#        (compared using ==)
#
#        Diff:
#        @@ -1,2 +1,2 @@
#        -[#<QuestionnaireQuestionsAnswer id: 1048181918, questionnaire_answer_id: 1016275382, questionnaire_question_id: 1061194242, manually_scored: true, given_score: 0.0
# , content: "", created_at: "2016-09-14 23:19:46", updated_at: "2016-09-14 23:19:46", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-07 23:19:46", curr
#
# ent: true, archived_at: nil>]
#        +[]
#
#      # ./spec/models/questionnaire_questions_answer_spec.rb:394:in `block (4 levels) in <top (required)>'
#
#   15) QuestionnaireQuestionsAnswer Class methods for Script .duration_before_doc_expiry should send notification before the duration of expiry
#      Failure/Error: result.should eq([@answer])
#
#        expected: [#<QuestionnaireQuestionsAnswer id: 1048181920, questionnaire_answer_id: 1016275384, questionnaire_question_id: 1061194246, manually_scored: true, given_s
# core: 0.0, content: "", created_at: "2016-09-14 23:19:47", updated_at: "2016-09-14 23:19:47", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-14 23:19:
# 47", current: true, archived_at: nil>]
#             got: []
#
#        (compared using ==)
#
#        Diff:
#        @@ -1,2 +1,2 @@
#        -[#<QuestionnaireQuestionsAnswer id: 1048181920, questionnaire_answer_id: 1016275384, questionnaire_question_id: 1061194246, manually_scored: true, given_score: 0.0
# , content: "", created_at: "2016-09-14 23:19:47", updated_at: "2016-09-14 23:19:47", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-14 23:19:47", curr
# ent: true, archived_at: nil>]
#        +[]
#
#      # ./spec/models/questionnaire_questions_answer_spec.rb:412:in `block (4 levels) in <top (required)>'
#   16) QuestionnaireQuestionsAnswer Class methods for Script .duration_before_doc_expiry should resend notification if last notification failed
#      Failure/Error: result.should eq([@answer])
#
#        expected: [#<QuestionnaireQuestionsAnswer id: 1048181922, questionnaire_answer_id: 1016275386, questionnaire_question_id: 1061194250, manually_scored: true, given_s
# core: 0.0, content: "", created_at: "2016-09-14 23:19:47", updated_at: "2016-09-14 23:19:47", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-13 23:19:
# 47", current: true, archived_at: nil>]
#             got: []
#
#        (compared using ==)
#
#        Diff:
#        @@ -1,2 +1,2 @@
#        -[#<QuestionnaireQuestionsAnswer id: 1048181922, questionnaire_answer_id: 1016275386, questionnaire_question_id: 1061194250, manually_scored: true, given_score: 0.0
# , content: "", created_at: "2016-09-14 23:19:47", updated_at: "2016-09-14 23:19:47", failed_answer: false, scored_by_human: false, expiry_date: "2016-10-13 23:19:47", curr
#
# ent: true, archived_at: nil>]
#        +[]
#
#      # ./spec/models/questionnaire_questions_answer_spec.rb:434:in `block (4 levels) in <top (required)>'
#
#   17) QuestionnaireQuestionsAnswer Class methods for Script .just_expired_doc should not send notification on the same day set as expiry_date
#      Failure/Error: result.should eq([])
#
#        expected: []
#             got: [#<QuestionnaireQuestionsAnswer id: 1048181931, questionnaire_answer_id: 1016275395, questionnaire_question_id: 1061194268, manually_scored: true, given_s
# core: 0.0, content: "", created_at: "2016-09-14 23:19:50", updated_at: "2016-09-14 23:19:50", failed_answer: false, scored_by_human: false, expiry_date: "2016-09-14 23:19:
# 50", current: true, archived_at: nil>]
#
#        (compared using ==)
#
#        Diff:
#        @@ -1,2 +1,2 @@
#        -[]
#        +[#<QuestionnaireQuestionsAnswer id: 1048181931, questionnaire_answer_id: 1016275395, questionnaire_question_id: 1061194268, manually_scored: true, given_score: 0.0
# , content: "", created_at: "2016-09-14 23:19:50", updated_at: "2016-09-14 23:19:50", failed_answer: false, scored_by_human: false, expiry_date: "2016-09-14 23:19:50", curr
# ent: true, archived_at: nil>]
#
#      # ./spec/models/questionnaire_questions_answer_spec.rb:516:in `block (4 levels) in <top (required)>'
#   18) SimDojo::EventParticipant Instance Methods for questionnaire answers expiry When need to notify periodically on the basis of frequency set periodic_notification_of_e
# xpired_answers should return true when matches the frequency set
#      Failure/Error: expect(event_participant.periodic_notification_of_expired_answers(@decision.created_at.to_date)).to eq(true)
#
#        expected: true
#             got: false
#
#        (compared using ==)
#      # ./spec/models/sim_dojo/event_participant_spec.rb:955:in `block (5 levels) in <top (required)>'
#
#   19) SimDojo::EventParticipant Instance Methods for questionnaire answers expiry When need to notify periodically on the basis of frequency set periodic_notification_of_e
# xpired_answers should return true when last notification failed
#      Failure/Error: expect(event_participant.periodic_notification_of_expired_answers(@decision.created_at.to_date)).to eq(true)
#
#
#        expected: true
#             got: false
#
#        (compared using ==)
#      # ./spec/models/sim_dojo/event_participant_spec.rb:962:in `block (5 levels) in <top (required)>'
#
#   20) SimDojo::EventParticipant Instance Methods for questionnaire answers expiry When need to notify periodically on the basis of frequency set periodic_notification_of_e
# xpired_answers should return true when notification failed in notifying in second loop of frequency
#      Failure/Error: expect(event_participant.periodic_notification_of_expired_answers(@decision.created_at.to_date)).to eq(true)
#
#        expected: true
#             got: false
#
#        (compared using ==)
#      # ./spec/models/sim_dojo/event_participant_spec.rb:979:in `block (5 levels) in <top (required)>'
# ```
#
#
# # Tests
#
#  - 99.36% test coverage!
#  - Failures:
#   - RSpec: nil, except as above.
#   - Jasmine: Only 2 specs, both fail on formatting currency. Legacy code?
#   - Rake test: 8 tests, 310 assertions, 1 failures, 1 errors
#
# # Lint
#
#  - Rubocop Offences: 19597, of which 10316 are line length violations. (Created .rubocop_todo.yml)
#  - Reek Smells: 4070 total warnings in app/ alone (Created .todo.reek)
#
# # Deprecation Warnings
#
#  - 622 revealed on running RSpec
#  - No count available, but **significant** numbers revealed on running `rake test`, especially in Carrierwave and some other gem dependencies.
#
# # Curiosities
#
#  - Someone appears to have occasionally used the subsumption operator (===) when it looks like they mean equality (==).
#   - This leads to some subtle issues if it's not intentional, though none of the existing tests seem to mind.
#   - It might be deliberate, better ask Nic.
#
#  - Lots of JS rather than CoffeeScript assets.
#   - Is this just because whoever created them doesn't know CS?
#
#  - Nic's personal details are in the test data. Might be worth mentioning to him that his address is committed to his GitHub.
#   - {"password"=>"password", "password_confirmation"=>"password", "name"=>"nicilike3@marketdojo.com", "position"=>"General Dogsbody", "address_line_1"=>"13 Green Lane", "town"=>"Godalming", "country"=>"UK", "postal_code"=>"GU6 3AA", "office_phone"=>"012345678", "industry"=>"Retail", "company_name"=>"Market Dojo", "website"=>"www.marketdojo.com", "turnover"=>"1", "years_in_business"=>"1", "number_of_employees"=>"1", "time_zone"=>"London", "market_dojo"=>"true", "accepted_t_and_c"=>"true"}
#
# # Potential First Moves
#
# Fix RSpec nondeterminism on Time based tests. This is potentially a serious issue and may result in false positives/false negatives on attempting to upgrade.
#
# Sort problematic Rubocop offences from unimportant ones (Duplicate methods need fixing. Line length warnings aren't a priority) and start dealing with them in rough order of importance.
#
# Sort problematic Reek smells from unimportant ones, deal with in order of importance.
#  - This is an excellent opportunity to refactor before upgrading.
#
# Find all TODO, NOTE etc comments (including those which should be but aren't!), check if they have been assigned issues on the issue tracker, date and attribute them if possible.
#
# Ask Nic about using GitHub issues and projects for ease of tagging, assigning and so on.
#
# Create documentation for setting up dev environment
#
# Document dependencies and their purposes, especially where we are using forks or direct GitHub links.
#
# Add numeric output for automated `rake test`, `rubocop`, `rspec` and `reek` testing to Jenkins; try to avoid having tens of thousands of warnings by having a human look at those. Automated filters can only take us so far.
#
# Investigate all deprecation warnings produced by the various runners. Those which can be fixed before moving up a Rails or Ruby version, fix; that will make the upgrade process considerably easier.
#
# # Update Path (Post- First Moves Actions)
#
# Move to Rails 4.0 from v3.2.22.3
#
#  - Next significant version of Rails
#  - Compatible with current (2.1.1) version of Ruby
#  - Recommended upgrade path exists
#
# Update Gem dependencies to R4.0 compatible versions
#
#  - Will have to check these individually for compatibility
#  - Generate new Rails 4.0 project and use that Gemfile plus all additional dependencies?
#  - Replace deprecated, unused or unmaintained gems where at all possible
#   - How deeply embedded is Comatose? That in particular could be an enormous task, especially with all the tests to rewrite.
#    - Write own CMS?
#    - Update Comatose to be a Rails 4.0 gem?
#    - Find new recommended R4.0 compatible CMS?
#   - Replace Squeel with BabySqueel
#    - Unsure how much this will break; best to check.
#
# Fix all the test failures this will cause
#  - 99%+ test coverage should make this relatively straightforward to check, although with the number of methods to check it will be quite time consuming.
#
# Repeat with Rails 4.1 and 4.2
#  - These will both work with current Ruby version
#  - Recognised upgrade paths
#  - Most 4.0 gems will work up to 4.2 without significant modification
#  - Ensures all the tests are up to scratch
#
# Evaluate position. Rails 5 has a lot of major breaking changes, and will also require moving to (at minimum) Ruby 2.2.2 and more probably Ruby 2.3.1 for forward compatibility:
#  - Another round of Gem updating/upgrading/replacing
#  - Rewriting a *lot* of the existing tests
#  - Updating Rubocop, Parser and Reek to the latest versions and running them again
#   - These will undoubtedly report a constellation of new and different errors due to the changes in syntax and method names that Ruby has undergone in the last few years.
#
# # Review Periods
#
# Documentation should be evaluated and updated at the beginning of each quarter.
#
# Dependencies (such as gems, especially those with native dependencies such as Nokogiri) should be evaluated and updated (if necessary and possible given compatibility constraints) at the beginning of each half.
#
# Core modules (Rails, CMS) should be evaluated and updated at each minor (x.**X**.x.x) and major (**X**.x.x.x) release, to prevent multi-step upgrades from being necessary in future.
