# %% [markdown]
# # MD First Steps
#
# - ~~Update wiki instructions for dev env~~
# - Record issues in Refactor milestone (Zoho bugtracker)
# - Diarise meeting to review issues noticed (appx 28th October 2pm)
# - ~~Market Dojo slack channel~~
#
# - Spinner for button with JS?
#
# **Time Allocations**
#
# - 60% head down dev
#  - Bugfixes **and** features
# - 20% ops/support
#  - 1st/2nd/3rd line support
#  - Webchat, email
# - 20% project management
#
# - Including ~10% admin
#
# **Questions**
#
# - ~~Are there testing logins? I've had to SQL hack myself a testing Admin account.
#  - Admin
#  - Host
#   - With Admin
#   - Without Admin
#  - Participant~~
#
#
# **Notes**
#
#  - Remember to use activities tracker. Potentially valuable tool.
#
#
# **Skillsets Needed in Team**
#
#  - Design/UX
#  - DBA
#
# **Discussions**
#
#  - Craig
#   - Content Marketing (commenting, blog posts, twitter etc - good for SEO)
#   - Potential links/places to comment or post
#
#  - Nic
#   - AWS
#   - GCloud comparison once access to AWS created
#   - Liberata move
#
#  - Alun
#   - Need external Skype number
